# %%
a=10
b=20
c=30
d=40
e=50
print(a,b,c,d,e)

a=2.4
b=4.5
c=6.6
d=5.5
e=5.2
print(a,b,c,d,e)

char1="eman"
char2="mishal"
char3="habiba"
char4="fizza"
char5="hajra"
print(char1,char2,char3,char4,char5)


a=14
b=2
print(a>b)

a=1
b=2
print(a>b)

a=10
b=10
print(a==b)

a=11
b=12
print(a!=b)

a=1
b=2
print(a>b)
# Out:
# 10 20 30 40 50
# 2.4 4.5 6.6 5.5 5.2
# eman mishal habiba fizza hajra
# True
# False
# True
# True
# False
